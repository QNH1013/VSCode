# %%
import matplotlib.pyplot as plt

plt.style.use("dark_background")

plt.figure(figsize=(10,8))
plt.plot([1.0,2.0,5.0], [1.0,6.0,9.0])
plt.xlabel("time")
plt.ylabel("displacement")
# Out:
# Text(0, 0.5, 'displacement')

# %%
import numpy as np 
print (np.random.randint(600))
# Out:
# 540
